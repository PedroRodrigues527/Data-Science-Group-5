# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from supervised_functions import *
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_15104\3959541434.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # 1. Load the dataset

# %%
# Load the apples dataset
apples = pd.read_csv('../datasets/apple_quality.csv')

# Encode target variable
label_encoder = LabelEncoder()
apples['Quality'] = label_encoder.fit_transform(apples['Quality'])

# %%
corr_quality(apples)
# Out:
# Correlation with target variable:
# Ripeness       0.264315
# Juiciness      0.260223
# Sweetness      0.250998
# Size           0.244007
# Crunchiness    0.012376
# Acidity        0.007697
# A_id           0.004875
# Weight         0.001421
# Name: Quality, dtype: float64

# %%
X_train, X_test, y_train, y_test = split_train_test(apples)

# %% [markdown]
# # 2. Train and evaluate models

# %%
train_eval_models(X_train, X_test, y_train, y_test)
# Out:
# Training XGBoost...
# Accuracy for XGBoost: 0.83375
# Classification Report for XGBoost:
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83       401
#            1       0.81      0.88      0.84       399
#
#     accuracy                           0.83       800
#    macro avg       0.84      0.83      0.83       800
# weighted avg       0.84      0.83      0.83       800
# Training SVM...
# Accuracy for SVM: 0.92875
# Classification Report for SVM:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       401
#            1       0.94      0.92      0.93       399
#
#     accuracy                           0.93       800
#    macro avg       0.93      0.93      0.93       800
# weighted avg       0.93      0.93      0.93       800
# Training Logistic Regression...
# Accuracy for Logistic Regression: 0.75375
# Classification Report for Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.75       401
#            1       0.75      0.75      0.75       399
#
#     accuracy                           0.75       800
#    macro avg       0.75      0.75      0.75       800
# weighted avg       0.75      0.75      0.75       800
# Training Naive Bayes...
# Accuracy for Naive Bayes: 0.7625
# Classification Report for Naive Bayes:
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77       401
#            1       0.77      0.75      0.76       399
#
#     accuracy                           0.76       800
#    macro avg       0.76      0.76      0.76       800
# weighted avg       0.76      0.76      0.76       800
# Training Decision Trees...
# Accuracy for Decision Trees: 0.74
# Classification Report for Decision Trees:
#               precision    recall  f1-score   support
#
#            0       0.69      0.86      0.77       401
#            1       0.81      0.62      0.70       399
#
#     accuracy                           0.74       800
#    macro avg       0.75      0.74      0.74       800
# weighted avg       0.75      0.74      0.74       800
# Training AdaBoost...
# C:\Users\pedro\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Accuracy for AdaBoost: 0.625
# Classification Report for AdaBoost:
#               precision    recall  f1-score   support
#
#            0       0.69      0.46      0.55       401
#            1       0.59      0.79      0.68       399
#
#     accuracy                           0.62       800
#    macro avg       0.64      0.63      0.61       800
# weighted avg       0.64      0.62      0.61       800
